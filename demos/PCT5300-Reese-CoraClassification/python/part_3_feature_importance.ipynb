# %% [markdown]
# ## CAS Connection
#
# ### Connect to the Cas Server

# %%
import swat
s = swat.CAS(host, port)
s.session.setLocale(locale="en_US") 
s.sessionProp.setSessOpt(timeout=864000)
# Out:
# + Elapsed: 0.000287s, user: 0.001s, mem: 0.256mb

# %% [markdown]
# # Document Classification
# ## Part 3: Build Lean Models using Feature Importance
# In this notebook, you will quantify feature importance to determine which features are most important to the models trained in Part 2. Three methods are presented: a standard method, split-based Gini feature importance which is built into the decisionTree action set, and two new methods (patent pending) which consider the network structure of the tree based models. These methods are called Betweenness Centrality Feature Importance and Leaf Based Feature Importance.

# %% [markdown]
# # Load Data
#
# The Cora data set is publicly available via [this hyperlink](https://linqs.soe.ucsc.edu/data).

# %%
import document_classification_scripts as scripts
import importlib
importlib.reload(scripts)
from document_classification_scripts import AttributeDict, nClasses, nWords, targetColumn, baseFeatureList
demo = scripts.Demo(s)
# Out:
# NOTE: Added action set 'sampling'.
# NOTE: Added action set 'pca'.
# NOTE: Added action set 'fedsql'.
# NOTE: Added action set 'deepLearn'.
# NOTE: Added action set 'network'.
# NOTE: Added action set 'transpose'.
# NOTE: Added action set 'table'.
# NOTE: Added action set 'builtins'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'autotune'.
# NOTE: Added action set 'session'.
# NOTE: Added action set 'decisionTree'.
# NOTE: Added action set 'aStore'.
# NOTE: Added action set 'aggregation'.

# %%
demo.loadRawData()
# Out:
# NOTE: Cloud Analytic Services made the uploaded file available as table CONTENT in caslib CASUSER(brrees).
# NOTE: The table CONTENT has been created in caslib CASUSER(brrees) from binary data uploaded to Cloud Analytic Services.
# NOTE: Cloud Analytic Services made the uploaded file available as table CITES in caslib CASUSER(brrees).
# NOTE: The table CITES has been created in caslib CASUSER(brrees) from binary data uploaded to Cloud Analytic Services.

# %% [markdown]
# # Data Preprocessing
# ### Creates a custom format definition for target labels

# %%
demo.defineTargetVariableFormat()
# Out:
# NOTE: Format library MYFMTLIB added. Format search update using parameter APPEND completed.

# %% [markdown]
# ### Partitions data into training and test

# %%
demo.loadOrPartitionData()
# Out:
# NOTE: Cloud Analytic Services added the caslib 'cora'.
# NOTE: Cloud Analytic Services made the file contentPartitioned.sashdat available as table CONTENTPARTITIONED in caslib CASUSER(brrees).
# NOTE: Cloud Analytic Services made the file contentTrain.sashdat available as table CONTENTTRAIN in caslib CASUSER(brrees).
# NOTE: Cloud Analytic Services made the file contentTest.sashdat available as table CONTENTTEST in caslib CASUSER(brrees).

# %% [markdown]
# ### Performs Principal Component Analysis (PCA)

# %%
nPca = 40
demo.performPca(nPca)
pcaFeatureList = [f"pca{i}" for i in range(1,nPca)]
# Out:
# WARNING: The variable w445 in table CONTENTTRAIN is constant.

# %% [markdown]
# ### Joins citations and training data targets

# %%
demo.joinTrainingTargets()
# Out:
# NOTE: Table CITESTRAIN was created in caslib CASUSER(brrees) with 3562 rows returned.
# NOTE: Table CITESCOMBINED was created in caslib CASUSER(brrees) with 5429 rows returned.

# %% [markdown]
# ## Generate Network Features

# %%
# %%capture
networkParam=AttributeDict({
    "useCentrality":True,
    "useNodeSimilarity":True,
    "useCommunity":True,
    "useCore":True
})

tableContentNetwork, networkFeatureList = demo.addNetworkFeatures(
    "contentTrain", "citesTrain", networkParam)
tableContentPartitionedNetwork, networkFeatureList = demo.addNetworkFeatures(
    "contentPartitioned", "citesCombined", networkParam)

tableContentNetworkPca, networkFeatureList = demo.addNetworkFeatures(
    "contentTrainPca", "citesTrain", networkParam)
tableContentPartitionedNetworkPca, networkFeatureList = demo.addNetworkFeatures(
    "contentPartitionedPca", "citesCombined", networkParam)

# %%
s.datastep.runCode(
    code = f"data contentTestNetwork; set {tableContentPartitionedNetwork}(where=(partition=0)); run;"
)
print(f"contentTestNetwork: (rows, cols) = {s.CASTable('contentTestNetwork').shape}")

s.datastep.runCode(
    code = f"data contentTestPcaNetwork; set {tableContentPartitionedNetworkPca}(where=(partition=0)); run;"
)
print(f"contentTestPcaNetwork: (rows, cols) = {s.CASTable('contentTestPcaNetwork').shape}")
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed',)).History will not be written to the database.
# contentTestNetwork: (rows, cols) = (542, 1485)
# contentTestPcaNetwork: (rows, cols) = (542, 92)

# %% [markdown]
# # Load the Autotuned Network+PCA Model (trained in Part 2)

# %% [markdown]
# Here we load the best hyperparameter configuration found by autotune, for the feature set using PCA and Network features. We again train a forest model using these hyperparameters in order to examine the feature importance values computed by the forestTrain action in the decisionTree action set.

# %%
networkPcaModelAuto = "networkPcaModelAuto"

# %%
bestConfig = demo.loadOrTuneForestModel(networkPcaModelAuto,
                           "contentTrainPcaNetwork",
                           pcaFeatureList + networkFeatureList
                          )
print(bestConfig)
# Out:
# NOTE: Cloud Analytic Services made the file networkPcaModelAutoAStore.sashdat available as table NETWORKPCAMODELAUTOASTORE in caslib CASUSER(brrees).
# NOTE: Cloud Analytic Services made the file networkPcaModelAuto.sashdat available as table NETWORKPCAMODELAUTO in caslib CASUSER(brrees).
# Best Configuration
#
#                                      Parameter       Value
# Name
# Evaluation                          Evaluation           9
# NTREE                          Number of Trees          63
# M                   Number of Variables to Try          66
# BOOTSTRAP                            Bootstrap  0.72222222
# MAXLEVEL                   Maximum Tree Levels          21
# NBINS                           Number of Bins          47
# Objective   Misclassification Error Percentage        9.06

# %% [markdown]
# ## Train PCA Forest Model

# %%
# %%time
resultsTrainNetworkPcaModelAuto = demo.trainForestModel(networkPcaModelAuto,
                 "contentTrainPcaNetwork",
                 pcaFeatureList + networkFeatureList,
                 forestParam=bestConfig)
# Out:
# NOTE: 6755422 bytes were written to the table "networkPcaModelAutoAStore" in the caslib "CASUSER(brrees)".
# CPU times: user 15.6 ms, sys: 0 ns, total: 15.6 ms
# Wall time: 12.5 s

# %% [markdown]
# # View Gini (Split Based) Feature Importances

# %%
topNCutoff=12

# %%
resultsTrainNetworkPcaModelAuto['DTreeVarImpInfo'].head(topNCutoff)
# Out:
# Forest for CONTENTTRAINPCANETWORK
#
#                            Variable  Importance        Std
# 0       core_out_Genetic_Algorithms  202.501823  83.936062
# 1    core_out_Probabilistic_Methods  191.616565  94.225540
# 2                   core_out_Theory  157.864192  74.408969
# 3               core_out_Case_Based  144.608804  70.726945
# 4   core_out_Reinforcement_Learning  121.608562  54.491919
# 5          core_out_Neural_Networks  102.232383  43.443420
# 6            core_out_Rule_Learning   97.366988  45.322815
# 7                              pca3   16.903084   3.368072
# 8         deg_in_Genetic_Algorithms   10.874430  19.279559
# 9                              pca1   10.382247   2.518907
# 10                             pca2    7.604690   3.005979
# 11                            pca10    7.440904   3.494351

# %% [markdown]
# # New Methods for Feature Importance Calculation
#
# The following function calls include prototype python implementations of two new alternative methods to the commonly used methods for calculating feature importance. Either of the three methods (split based feature importance above, or the two methods below) can be used to determine a smaller feature set to use for the next iteration of model building.

# %% [markdown]
# ## Calculate and View Betweenness Feature Importances (patent pending)

# %%
demo.calculateBetweennessImportance(networkPcaModelAuto, casOut="betweennessImportances")
# Out:
# NOTE: The number of nodes in the input graph is 8097.
# NOTE: The number of links in the input graph is 8034.
# NOTE: Processing centrality metrics.
# NOTE: Processing centrality metrics used 0.04 (cpu: 0.64) seconds.

# %%
s.CASTable("betweennessImportances").nlargest(topNCutoff,"betweenImportance")
# Out:
# Selected Rows from Table BETWEENNESSIMPORTANCES
#
#                            Variable  betweenImportance
# 0          core_out_Neural_Networks           0.016174
# 1                   core_out_Theory           0.013138
# 2   core_out_Reinforcement_Learning           0.011181
# 3    core_out_Probabilistic_Methods           0.010852
# 4                              pca3           0.008360
# 5               core_out_Case_Based           0.008340
# 6            core_out_Rule_Learning           0.008216
# 7         deg_in_Genetic_Algorithms           0.006130
# 8                              pca2           0.005769
# 9                              pca1           0.005418
# 10      core_out_Genetic_Algorithms           0.005227
# 11                            pca10           0.004289

# %% [markdown]
# ## Calculate and View Leaf Based Feature Importances (patent pending)

# %%
classes = [
    "Rule_Learning",
    "Theory",
    "Genetic_Algorithms",
    "Reinforcement_Learning",
    "Case_Based",
    "Neural_Networks",
    "Probabilistic_Methods"
]

# %%
leafBasedImportances = demo.leafBasedImportances(networkPcaModelAuto,
                 "contentTrainPcaNetwork",
                 pcaFeatureList + networkFeatureList,
                 classes
                )
# Out:
# tree 1 of 63
# tree 2 of 63
# tree 3 of 63
# tree 4 of 63
# tree 5 of 63
# tree 6 of 63
# tree 7 of 63
# tree 8 of 63
# tree 9 of 63
# tree 10 of 63
# tree 11 of 63
# tree 12 of 63
# tree 13 of 63
# tree 14 of 63
# tree 15 of 63
# tree 16 of 63
# tree 17 of 63
# tree 18 of 63
# tree 19 of 63
# tree 20 of 63
# tree 21 of 63
# tree 22 of 63
# tree 23 of 63
# tree 24 of 63
# tree 25 of 63
# tree 26 of 63
# tree 27 of 63
# tree 28 of 63
# tree 29 of 63
# tree 30 of 63
# tree 31 of 63
# tree 32 of 63
# tree 33 of 63
# tree 34 of 63
# tree 35 of 63
# tree 36 of 63
# tree 37 of 63
# tree 38 of 63
# tree 39 of 63
# tree 40 of 63
# tree 41 of 63
# tree 42 of 63
# tree 43 of 63
# tree 44 of 63
# tree 45 of 63
# tree 46 of 63
# tree 47 of 63
# tree 48 of 63
# tree 49 of 63
# tree 50 of 63
# tree 51 of 63
# tree 52 of 63
# tree 53 of 63
# tree 54 of 63
# tree 55 of 63
# tree 56 of 63
# tree 57 of 63
# tree 58 of 63
# tree 59 of 63
# tree 60 of 63
# tree 61 of 63
# tree 62 of 63
# tree 63 of 63

# %%
rankedFeaturesLeafBased = scripts.printImportances(leafBasedImportances, topNCutoff)
# Out:
#               core_out_Rule_Learning:  28290.745613
#          core_out_Genetic_Algorithms:  27315.230665
#                  core_out_Case_Based:  21857.950878
#      core_out_Reinforcement_Learning:  11610.907497
#       core_out_Probabilistic_Methods:  8518.756256
#                      core_out_Theory:  4120.936694
#            deg_in_Genetic_Algorithms:  3317.974407
#             core_out_Neural_Networks:  2512.329228
#                 deg_in_Rule_Learning:   720.522850
#                                 pca3:   502.303616
#                                 pca2:   414.799033
#                    deg_in_Case_Based:   208.073518

# %%
rankedFeaturesSplitBased = resultsTrainNetworkPcaModelAuto['DTreeVarImpInfo']['Variable'].tolist()[0:topNCutoff]
rankedFeaturesBetweenness = s.CASTable("betweennessImportances").nlargest(topNCutoff,"betweenImportance")["Variable"].tolist()

# %% [markdown]
# Note that split based Gini feature importance and Betweenness feature importance produce the same set of top 12 features.
#
# Leaf Based feature importance, on the other hand includes two features (generated from network in-degree) and excludes two features (from PCA) in its top 12:

# %%
a=set(rankedFeaturesLeafBased) - set(rankedFeaturesBetweenness)
b=set(rankedFeaturesBetweenness) - set(rankedFeaturesLeafBased)
print(f"""In Leaf Based Top {topNCutoff}, but not Betweenness Top {topNCutoff}:
   {a}""")
print(f"""In Betweenness Top {topNCutoff}, but not Leaf Based Top {topNCutoff}:
   {b}""")

a=set(rankedFeaturesLeafBased) - set(rankedFeaturesSplitBased)
b=set(rankedFeaturesSplitBased) - set(rankedFeaturesLeafBased)
print(f"""
In Leaf Based Top {topNCutoff}, but not Split Based Top {topNCutoff}:
   {a}""")
print(f"""In Split Based Top {topNCutoff}, but not Leaf Based Top {topNCutoff}:
   {b}""")

a=set(rankedFeaturesSplitBased) - set(rankedFeaturesBetweenness)
b=set(rankedFeaturesBetweenness) - set(rankedFeaturesSplitBased)
print(f"""
In Split Based Top {topNCutoff}, but not Betweenness Top {topNCutoff}:
   {a}""")
print(f"""In Betweenness Top {topNCutoff}, but not Split Based Top {topNCutoff}:
   {b}""")
# Out:
# In Leaf Based Top 12, but not Betweenness Top 12:
#    {'deg_in_Case_Based', 'deg_in_Rule_Learning'}
# In Betweenness Top 12, but not Leaf Based Top 12:
#    {'pca10', 'pca1'}
#
# In Leaf Based Top 12, but not Split Based Top 12:
#    {'deg_in_Case_Based', 'deg_in_Rule_Learning'}
# In Split Based Top 12, but not Leaf Based Top 12:
#    {'pca10', 'pca1'}
#
# In Split Based Top 12, but not Betweenness Top 12:
#    set()
# In Betweenness Top 12, but not Split Based Top 12:
#    set()

# %% [markdown]
# # Build models using only top N features

# %% [markdown]
# The best-performing models from Part 1 and Part 2 use a total of 85 features -- 40 PCA features and 45 Network features.
#
# Can we achieve similar model performance by using only the 12 most important features?

# %% [markdown]
# # First, try the top 12 features by Split Based Feature Importance

# %%
topNFeatureList = rankedFeaturesSplitBased
topNFeatureList
# Out:
# ['core_out_Genetic_Algorithms',
#  'core_out_Probabilistic_Methods',
#  'core_out_Theory',
#  'core_out_Case_Based',
#  'core_out_Reinforcement_Learning',
#  'core_out_Neural_Networks',
#  'core_out_Rule_Learning',
#  'pca3',
#  'deg_in_Genetic_Algorithms',
#  'pca1',
#  'pca2',
#  'pca10']

# %% [markdown]
# ## Train Neural Net Model Using Top N Split Based Features

# %%
deepLearnParam = AttributeDict({
    "randomSeed": 1337,
    "dropout": 0.5,
    "activation": "RECTIFIER",
    "outputActivation": "SOFTMAX",
    "denseLayers": [50, 50],
    "nOutputs": nClasses,
    "nEpochs": 100,
    "algoMethod": "ADAM",
    "useLocking": False
})

# %%
topNNnModel = "topNNnModelSplit"
demo.defineNnModel(topNNnModel, deepLearnParam)

# %%
# %%time
demo.trainNnModel(topNNnModel,"contentTrainPcaNetwork", topNFeatureList, deepLearnParam)
# Out:
# CPU times: user 46.9 ms, sys: 0 ns, total: 46.9 ms
# Wall time: 1.15 s
# [ModelInfo]
#
#                                         Descr                Value
#  0                                 Model Name     topnnnmodelsplit
#  1                                 Model Type  Deep Neural Network
#  2                           Number of Layers                    4
#  3                     Number of Input Layers                    1
#  4                    Number of Output Layers                    1
#  5           Number of Fully Connected Layers                    2
#  6                Number of Weight Parameters                 3450
#  7                  Number of Bias Parameters                  107
#  8           Total Number of Model Parameters                 3557
#  9  Approximate Memory Cost for Training (MB)                    1
#
# [OptIterHistory]
#
#      Epoch  LearningRate      Loss  FitError
#  0     0.0         0.001  1.795905  0.674977
#  1     1.0         0.001  1.539395  0.554017
#  2     2.0         0.001  1.346250  0.465836
#  3     3.0         0.001  1.245496  0.408587
#  4     4.0         0.001  1.143274  0.385042
#  5     5.0         0.001  1.044882  0.341182
#  6     6.0         0.001  1.002767  0.338412
#  7     7.0         0.001  0.941305  0.314404
#  8     8.0         0.001  0.895646  0.303786
#  9     9.0         0.001  0.865053  0.276085
#  10   10.0         0.001  0.801499  0.253001
#  11   11.0         0.001  0.767549  0.244229
#  12   12.0         0.001  0.748901  0.239151
#  13   13.0         0.001  0.723805  0.231302
#  14   14.0         0.001  0.684991  0.216066
#  15   15.0         0.001  0.634624  0.187904
#  16   16.0         0.001  0.622895  0.198984
#  17   17.0         0.001  0.611270  0.189751
#  18   18.0         0.001  0.571234  0.164820
#  19   19.0         0.001  0.561626  0.172207
#  20   20.0         0.001  0.526183  0.168513
#  21   21.0         0.001  0.522336  0.157433
#  22   22.0         0.001  0.509470  0.159280
#  23   23.0         0.001  0.499999  0.150046
#  24   24.0         0.001  0.489533  0.140813
#  25   25.0         0.001  0.474810  0.140813
#  26   26.0         0.001  0.471257  0.150970
#  27   27.0         0.001  0.449406  0.133426
#  28   28.0         0.001  0.450693  0.138504
#  29   29.0         0.001  0.434077  0.124654
#  ..    ...           ...       ...       ...
#  70   70.0         0.001  0.329714  0.108033
#  71   71.0         0.001  0.323344  0.100185
#  72   72.0         0.001  0.341096  0.108957
#  73   73.0         0.001  0.343463  0.110342
#  74   74.0         0.001  0.334231  0.102031
#  75   75.0         0.001  0.341452  0.105725
#  76   76.0         0.001  0.319367  0.101108
#  77   77.0         0.001  0.335091  0.105725
#  78   78.0         0.001  0.354490  0.106648
#  79   79.0         0.001  0.326990  0.105725
#  80   80.0         0.001  0.311941  0.102955
#  81   81.0         0.001  0.344932  0.107572
#  82   82.0         0.001  0.319888  0.100185
#  83   83.0         0.001  0.335531  0.113573
#  84   84.0         0.001  0.311885  0.098800
#  85   85.0         0.001  0.313858  0.100185
#  86   86.0         0.001  0.321876  0.108495
#  87   87.0         0.001  0.317889  0.102493
#  88   88.0         0.001  0.318136  0.100185
#  89   89.0         0.001  0.323192  0.105263
#  90   90.0         0.001  0.317259  0.098800
#  91   91.0         0.001  0.314470  0.101570
#  92   92.0         0.001  0.317629  0.106648
#  93   93.0         0.001  0.330173  0.108495
#  94   94.0         0.001  0.309522  0.092336
#  95   95.0         0.001  0.328022  0.108495
#  96   96.0         0.001  0.312373  0.107572
#  97   97.0         0.001  0.303583  0.097415
#  98   98.0         0.001  0.306709  0.099261
#  99   99.0         0.001  0.301563  0.108495
#
#  [100 rows x 4 columns]
#
# [OutputCasTables]
#
#              casLib                     Name  Rows  Columns  \
#  0  CASUSER(brrees)  topNNnModelSplitWeights  3557        3
#
#                                              casTable
#  0  CASTable('topNNnModelSplitWeights', caslib='CA...
#
# + Elapsed: 1.09s, user: 4.67s, sys: 0.704s, mem: 38.2mb

# %%
demo.scoreNnModel(topNNnModel,"contentTestPcaNetwork")
# Out:
#                          Descr         Value
# 0  Number of Observations Read           542
# 1  Number of Observations Used           542
# 2  Misclassification Error (%)      11.99262
# 3                   Loss Error      0.487157
# Accuracy = 0.8800738
# 0.8800738

# %% [markdown]
# ### Bootstrap Runs

# %%
# %%time
accuracies = demo.bootstrapNnModel(topNNnModel,"contentTrainPcaNetwork",
                                   "contentTestPcaNetwork",
                                   topNFeatureList,
                                   deepLearnParam,
                                   25
                                  );
# Out:
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5678 for sampling.
# Accuracy = 0.8790984000000001
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5679 for sampling.
# Accuracy = 0.8770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5680 for sampling.
# Accuracy = 0.8872951
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5681 for sampling.
# Accuracy = 0.8709015999999999
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5682 for sampling.
# Accuracy = 0.8852459
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5683 for sampling.
# Accuracy = 0.8811475
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5684 for sampling.
# Accuracy = 0.8811475
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5685 for sampling.
# Accuracy = 0.8852459
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5686 for sampling.
# Accuracy = 0.8770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5687 for sampling.
# Accuracy = 0.8770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5688 for sampling.
# Accuracy = 0.8770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5689 for sampling.
# Accuracy = 0.8831967000000001
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5690 for sampling.
# Accuracy = 0.8729508
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5691 for sampling.
# Accuracy = 0.8770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5692 for sampling.
# Accuracy = 0.8770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5693 for sampling.
# Accuracy = 0.875
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5694 for sampling.
# Accuracy = 0.8770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5695 for sampling.
# Accuracy = 0.8790984000000001
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5696 for sampling.
# Accuracy = 0.8729508
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5697 for sampling.
# Accuracy = 0.8872951
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5698 for sampling.
# Accuracy = 0.8811475
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5699 for sampling.
# Accuracy = 0.8770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5700 for sampling.
# Accuracy = 0.8852459
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5701 for sampling.
# Accuracy = 0.8852459
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5702 for sampling.
# Accuracy = 0.8790984000000001
# Bootstrap Accuracy = 0.8795082 +- 0.0044895302673665215
# CPU times: user 3.27 s, sys: 109 ms, total: 3.38 s
# Wall time: 33.5 s

# %% [markdown]
# ## Train Forest Model Using Top N Split Based Features

# %%
topNForestModel = "topNForestModelSplit"

# %%
# %%time
demo.trainForestModel(
    topNForestModel, "contentTrainPcaNetwork", topNFeatureList)
# Out:
# NOTE: 1372882 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# CPU times: user 15.6 ms, sys: 0 ns, total: 15.6 ms
# Wall time: 301 ms
# [ModelInfo]
#
#  Forest for CONTENTTRAINPCANETWORK
#
#                                 Descr         Value
#  0                    Number of Trees     50.000000
#  1   Number of Selected Variables (M)      4.000000
#  2                 Random Number Seed  12345.000000
#  3           Bootstrap Percentage (%)     63.212056
#  4                     Number of Bins     50.000000
#  5                Number of Variables     12.000000
#  6       Confidence Level for Pruning      0.250000
#  7           Max Number of Tree Nodes     43.000000
#  8           Min Number of Tree Nodes     25.000000
#  9             Max Number of Branches      2.000000
#  10            Min Number of Branches      2.000000
#  11              Max Number of Levels      6.000000
#  12              Min Number of Levels      6.000000
#  13              Max Number of Leaves     22.000000
#  14              Min Number of Leaves     13.000000
#  15            Maximum Size of Leaves    857.000000
#  16            Minimum Size of Leaves      5.000000
#  17                Out-of-Bag MCR (%)           NaN
#  18          Average number of Leaves     17.740000
#
# [DTreeVarImpInfo]
#
#  Forest for CONTENTTRAINPCANETWORK
#
#                             Variable  Importance        Std
#  0       core_out_Genetic_Algorithms  129.630012  84.690007
#  1               core_out_Case_Based  108.441181  61.202702
#  2    core_out_Probabilistic_Methods  101.093844  81.521286
#  3          core_out_Neural_Networks  100.689179  89.778221
#  4            core_out_Rule_Learning   70.951737  38.078643
#  5   core_out_Reinforcement_Learning   56.386130  41.892267
#  6                   core_out_Theory   56.090930  55.524760
#  7         deg_in_Genetic_Algorithms   15.455629  62.070077
#  8                              pca3    6.644762  11.032325
#  9                              pca1    4.594636   7.703717
#  10                             pca2    3.088815   5.854517
#  11                            pca10    1.451741   2.478268
#
# [OutputCasTables]
#
#              casLib                  Name  Rows  Columns  \
#  0  CASUSER(brrees)  topNForestModelSplit  1724       35
#
#                                              casTable
#  0  CASTable('topNForestModelSplit', caslib='CASUS...
#
# + Elapsed: 0.287s, user: 1.31s, sys: 0.588s, mem: 172mb

# %%
resultsScoreTopNForestModel=demo.scoreForestModel(topNForestModel,"contentTestPcaNetwork")
# Out:
# Accuracy = 0.7915129151291513

# %% [markdown]
# ### Bootstrap Runs

# %%
# %%time
accuracies = demo.bootstrapForestModel(topNForestModel,"contentTrainPcaNetwork",
                                       "contentTestPcaNetwork",
                                       topNFeatureList,
                                       n=25
                                      );
# Out:
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5678 for sampling.
# NOTE: 1372882 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7930327868852459
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5679 for sampling.
# NOTE: 1375986 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7889344262295082
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5680 for sampling.
# NOTE: 1377594 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7889344262295082
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5681 for sampling.
# NOTE: 1372866 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7889344262295082
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5682 for sampling.
# NOTE: 1374442 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7930327868852459
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5683 for sampling.
# NOTE: 1371258 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7991803278688525
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5684 for sampling.
# NOTE: 1377626 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7868852459016393
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5685 for sampling.
# NOTE: 1372882 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7950819672131147
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5686 for sampling.
# NOTE: 1379202 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7807377049180327
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5687 for sampling.
# NOTE: 1379234 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7868852459016393
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5688 for sampling.
# NOTE: 1382434 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7807377049180327
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5689 for sampling.
# NOTE: 1387194 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7868852459016393
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5690 for sampling.
# NOTE: 1382450 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7827868852459017
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5691 for sampling.
# NOTE: 1380858 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.805327868852459
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5692 for sampling.
# NOTE: 1379298 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7848360655737705
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5693 for sampling.
# NOTE: 1379250 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7868852459016393
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5694 for sampling.
# NOTE: 1376098 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7950819672131147
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5695 for sampling.
# NOTE: 1374538 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7868852459016393
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5696 for sampling.
# NOTE: 1376146 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7786885245901639
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5697 for sampling.
# NOTE: 1371370 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7971311475409836
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5698 for sampling.
# NOTE: 1372946 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8012295081967213
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5699 for sampling.
# NOTE: 1368186 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7889344262295082
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5700 for sampling.
# NOTE: 1369762 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7991803278688525
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5701 for sampling.
# NOTE: 1368186 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7971311475409836
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5702 for sampling.
# NOTE: 1369762 bytes were written to the table "topNForestModelSplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7950819672131147
# Bootstrap Accuracy = 0.7907377049180327 +- 0.006767136865754207
# CPU times: user 3.7 s, sys: 141 ms, total: 3.84 s
# Wall time: 13.8 s

# %% [markdown]
# ## Autotune Forest Model Using Top N Split Based Features

# %%
topNForestModelAuto = f"topNForestModelAuto{topNCutoff}Split"

# %%
# %%time
bestConfigTopN = demo.loadOrTuneForestModel(topNForestModelAuto,
                           "contentTrainPcaNetwork",
                           topNFeatureList
                          )
print(bestConfigTopN)
# Out:
# NOTE: Cloud Analytic Services made the file topNForestModelAuto12SplitAStore.sashdat available as table TOPNFORESTMODELAUTO12SPLITASTORE in caslib CASUSER(brrees).
# NOTE: Cloud Analytic Services made the file topNForestModelAuto12Split.sashdat available as table TOPNFORESTMODELAUTO12SPLIT in caslib CASUSER(brrees).
# Best Configuration
#
#                                      Parameter       Value
# Name
# Evaluation                          Evaluation          80
# NTREE                          Number of Trees          97
# M                   Number of Variables to Try           4
# BOOTSTRAP                            Bootstrap  0.20613305
# MAXLEVEL                   Maximum Tree Levels          15
# NBINS                           Number of Bins          44
# Objective   Misclassification Error Percentage        9.22
# CPU times: user 31.2 ms, sys: 0 ns, total: 31.2 ms
# Wall time: 106 ms

# %%
resultsScoreTopNForestModelAuto=demo.scoreForestModel(topNForestModelAuto,"contentTestPcaNetwork")
# Out:
# Accuracy = 0.8634686346863468

# %% [markdown]
# ### Bootstrap Runs

# %%
# %%time
accuracies = demo.bootstrapForestModel(topNForestModelAuto,"contentTrainPcaNetwork",
                                       "contentTestPcaNetwork",
                                       topNFeatureList,
                                       bestConfigTopN,
                                       25
                                      );
# Out:
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5678 for sampling.
# NOTE: 4961890 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8627049180327869
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5679 for sampling.
# NOTE: 4958370 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8668032786885246
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5680 for sampling.
# NOTE: 4956810 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8647540983606558
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5681 for sampling.
# NOTE: 4946458 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8586065573770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5682 for sampling.
# NOTE: 4933626 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8688524590163934
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5683 for sampling.
# NOTE: 4931650 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8647540983606558
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5684 for sampling.
# NOTE: 4936058 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.860655737704918
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5685 for sampling.
# NOTE: 4940930 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8688524590163934
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5686 for sampling.
# NOTE: 4926266 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8565573770491803
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5687 for sampling.
# NOTE: 4916026 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8586065573770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5688 for sampling.
# NOTE: 4917794 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8565573770491803
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5689 for sampling.
# NOTE: 4924530 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8668032786885246
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5690 for sampling.
# NOTE: 4918402 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.860655737704918
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5691 for sampling.
# NOTE: 4921970 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8729508196721312
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5692 for sampling.
# NOTE: 4905298 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8586065573770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5693 for sampling.
# NOTE: 4905394 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8524590163934426
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5694 for sampling.
# NOTE: 4891938 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.860655737704918
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5695 for sampling.
# NOTE: 4895378 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8627049180327869
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5696 for sampling.
# NOTE: 4882274 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8627049180327869
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5697 for sampling.
# NOTE: 4889170 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8729508196721312
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5698 for sampling.
# NOTE: 4892098 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8688524590163934
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5699 for sampling.
# NOTE: 4887418 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8647540983606558
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5700 for sampling.
# NOTE: 4893930 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8668032786885246
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5701 for sampling.
# NOTE: 4882498 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8688524590163934
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5702 for sampling.
# NOTE: 4873786 bytes were written to the table "topNForestModelAuto12SplitAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8668032786885246
# Bootstrap Accuracy = 0.8637704918032787 +- 0.005122786882622873
# CPU times: user 3.34 s, sys: 156 ms, total: 3.5 s
# Wall time: 28.6 s

# %% [markdown]
# # Now, try the top 12 features by Leaf Based Feature Importance

# %%
topNFeatureList = rankedFeaturesLeafBased
topNFeatureList
# Out:
# ['core_out_Rule_Learning',
#  'core_out_Genetic_Algorithms',
#  'core_out_Case_Based',
#  'core_out_Reinforcement_Learning',
#  'core_out_Probabilistic_Methods',
#  'core_out_Theory',
#  'deg_in_Genetic_Algorithms',
#  'core_out_Neural_Networks',
#  'deg_in_Rule_Learning',
#  'pca3',
#  'pca2',
#  'deg_in_Case_Based']

# %% [markdown]
# ## Train Neural Net Model Using Top N Leaf Based Features

# %%
deepLearnParam = AttributeDict({
    "randomSeed": 1337,
    "dropout": 0.5,
    "activation": "RECTIFIER",
    "outputActivation": "SOFTMAX",
    "denseLayers": [50, 50],
    "nOutputs": nClasses,
    "nEpochs": 100,
    "algoMethod": "ADAM",
    "useLocking": False
})

# %%
topNNnModel = "topNNnModelLeaf"
demo.defineNnModel(topNNnModel, deepLearnParam)

# %%
# %%time
demo.trainNnModel(topNNnModel,"contentTrainPcaNetwork", topNFeatureList, deepLearnParam)
# Out:
# CPU times: user 62.5 ms, sys: 0 ns, total: 62.5 ms
# Wall time: 1.17 s
# [ModelInfo]
#
#                                         Descr                Value
#  0                                 Model Name      topnnnmodelleaf
#  1                                 Model Type  Deep Neural Network
#  2                           Number of Layers                    4
#  3                     Number of Input Layers                    1
#  4                    Number of Output Layers                    1
#  5           Number of Fully Connected Layers                    2
#  6                Number of Weight Parameters                 3450
#  7                  Number of Bias Parameters                  107
#  8           Total Number of Model Parameters                 3557
#  9  Approximate Memory Cost for Training (MB)                    1
#
# [OptIterHistory]
#
#      Epoch  LearningRate      Loss  FitError
#  0     0.0         0.001  1.799952  0.699908
#  1     1.0         0.001  1.529331  0.567405
#  2     2.0         0.001  1.347158  0.467221
#  3     3.0         0.001  1.210284  0.404894
#  4     4.0         0.001  1.098087  0.351801
#  5     5.0         0.001  0.981098  0.311634
#  6     6.0         0.001  0.917063  0.267775
#  7     7.0         0.001  0.827239  0.242382
#  8     8.0         0.001  0.762579  0.228532
#  9     9.0         0.001  0.712670  0.213296
#  10   10.0         0.001  0.656046  0.199446
#  11   11.0         0.001  0.637984  0.195753
#  12   12.0         0.001  0.615758  0.181902
#  13   13.0         0.001  0.595765  0.174515
#  14   14.0         0.001  0.544203  0.162973
#  15   15.0         0.001  0.562129  0.169437
#  16   16.0         0.001  0.527100  0.149123
#  17   17.0         0.001  0.525153  0.158818
#  18   18.0         0.001  0.510130  0.155125
#  19   19.0         0.001  0.507442  0.140813
#  20   20.0         0.001  0.486833  0.135272
#  21   21.0         0.001  0.494155  0.138504
#  22   22.0         0.001  0.493166  0.144506
#  23   23.0         0.001  0.472435  0.137581
#  24   24.0         0.001  0.462486  0.139889
#  25   25.0         0.001  0.463323  0.134349
#  26   26.0         0.001  0.457034  0.139428
#  27   27.0         0.001  0.441982  0.132041
#  28   28.0         0.001  0.450863  0.133426
#  29   29.0         0.001  0.448016  0.138504
#  ..    ...           ...       ...       ...
#  70   70.0         0.001  0.346514  0.109418
#  71   71.0         0.001  0.358773  0.117267
#  72   72.0         0.001  0.356110  0.109880
#  73   73.0         0.001  0.354583  0.105725
#  74   74.0         0.001  0.365966  0.109418
#  75   75.0         0.001  0.361077  0.109418
#  76   76.0         0.001  0.375148  0.118652
#  77   77.0         0.001  0.338237  0.106648
#  78   78.0         0.001  0.351251  0.106187
#  79   79.0         0.001  0.356617  0.117729
#  80   80.0         0.001  0.338406  0.106648
#  81   81.0         0.001  0.338143  0.101108
#  82   82.0         0.001  0.344450  0.108957
#  83   83.0         0.001  0.355987  0.105725
#  84   84.0         0.001  0.359228  0.110342
#  85   85.0         0.001  0.342477  0.105725
#  86   86.0         0.001  0.367960  0.107572
#  87   87.0         0.001  0.348062  0.111265
#  88   88.0         0.001  0.337047  0.102493
#  89   89.0         0.001  0.333819  0.106187
#  90   90.0         0.001  0.349425  0.110342
#  91   91.0         0.001  0.343960  0.116343
#  92   92.0         0.001  0.345935  0.110342
#  93   93.0         0.001  0.342630  0.104340
#  94   94.0         0.001  0.341187  0.109418
#  95   95.0         0.001  0.352143  0.111727
#  96   96.0         0.001  0.338309  0.102493
#  97   97.0         0.001  0.354346  0.111727
#  98   98.0         0.001  0.334880  0.112188
#  99   99.0         0.001  0.318815  0.106648
#
#  [100 rows x 4 columns]
#
# [OutputCasTables]
#
#              casLib                    Name  Rows  Columns  \
#  0  CASUSER(brrees)  topNNnModelLeafWeights  3557        3
#
#                                              casTable
#  0  CASTable('topNNnModelLeafWeights', caslib='CAS...
#
# + Elapsed: 1.11s, user: 4.8s, sys: 0.698s, mem: 37.9mb

# %%
demo.scoreNnModel(topNNnModel,"contentTestPcaNetwork")
# Out:
#                          Descr         Value
# 0  Number of Observations Read           542
# 1  Number of Observations Used           542
# 2  Misclassification Error (%)      12.73063
# 3                   Loss Error      0.512408
# Accuracy = 0.8726936999999999
# 0.8726936999999999

# %% [markdown]
# ### Bootstrap Runs

# %%
# %%time
accuracies = demo.bootstrapNnModel(topNNnModel,"contentTrainPcaNetwork",
                                   "contentTestPcaNetwork",
                                   topNFeatureList,
                                   deepLearnParam,
                                   25
                                  );
# Out:
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5678 for sampling.
# Accuracy = 0.8709015999999999
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5679 for sampling.
# Accuracy = 0.8709015999999999
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5680 for sampling.
# Accuracy = 0.8729508
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5681 for sampling.
# Accuracy = 0.8647541
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5682 for sampling.
# Accuracy = 0.8811475
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5683 for sampling.
# Accuracy = 0.8790984000000001
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5684 for sampling.
# Accuracy = 0.8729508
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5685 for sampling.
# Accuracy = 0.8790984000000001
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5686 for sampling.
# Accuracy = 0.8668032999999999
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5687 for sampling.
# Accuracy = 0.8688525
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5688 for sampling.
# Accuracy = 0.8668032999999999
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5689 for sampling.
# Accuracy = 0.8770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5690 for sampling.
# Accuracy = 0.8606556999999999
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5691 for sampling.
# Accuracy = 0.8709015999999999
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5692 for sampling.
# Accuracy = 0.8688525
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5693 for sampling.
# Accuracy = 0.8627049
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5694 for sampling.
# Accuracy = 0.8668032999999999
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5695 for sampling.
# Accuracy = 0.8688525
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5696 for sampling.
# Accuracy = 0.8709015999999999
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5697 for sampling.
# Accuracy = 0.8790984000000001
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5698 for sampling.
# Accuracy = 0.875
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5699 for sampling.
# Accuracy = 0.8709015999999999
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5700 for sampling.
# Accuracy = 0.875
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5701 for sampling.
# Accuracy = 0.875
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5702 for sampling.
# Accuracy = 0.8770492
# Bootstrap Accuracy = 0.8717213119999998 +- 0.005280373695057598
# CPU times: user 3.34 s, sys: 78.1 ms, total: 3.42 s
# Wall time: 40 s

# %% [markdown]
# ## Train Forest Model Using Top N Leaf Based Features

# %%
topNForestModel = "topNForestModelLeaf"

# %%
# %%time
demo.trainForestModel(
    topNForestModel, "contentTrainPcaNetwork", topNFeatureList)
# Out:
# NOTE: 1323010 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# CPU times: user 15.6 ms, sys: 0 ns, total: 15.6 ms
# Wall time: 303 ms
# [ModelInfo]
#
#  Forest for CONTENTTRAINPCANETWORK
#
#                                 Descr         Value
#  0                    Number of Trees     50.000000
#  1   Number of Selected Variables (M)      4.000000
#  2                 Random Number Seed  12345.000000
#  3           Bootstrap Percentage (%)     63.212056
#  4                     Number of Bins     50.000000
#  5                Number of Variables     12.000000
#  6       Confidence Level for Pruning      0.250000
#  7           Max Number of Tree Nodes     41.000000
#  8           Min Number of Tree Nodes     23.000000
#  9             Max Number of Branches      2.000000
#  10            Min Number of Branches      2.000000
#  11              Max Number of Levels      6.000000
#  12              Min Number of Levels      6.000000
#  13              Max Number of Leaves     21.000000
#  14              Min Number of Leaves     12.000000
#  15            Maximum Size of Leaves    808.000000
#  16            Minimum Size of Leaves      5.000000
#  17                Out-of-Bag MCR (%)           NaN
#  18          Average number of Leaves     17.100000
#
# [DTreeVarImpInfo]
#
#  Forest for CONTENTTRAINPCANETWORK
#
#                             Variable  Importance        Std
#  0       core_out_Genetic_Algorithms  145.566501  83.829538
#  1          core_out_Neural_Networks  113.372868  87.590736
#  2    core_out_Probabilistic_Methods  108.853599  80.218830
#  3               core_out_Case_Based   88.623363  59.056901
#  4   core_out_Reinforcement_Learning   61.260201  43.966310
#  5            core_out_Rule_Learning   61.160922  34.722224
#  6                   core_out_Theory   58.169529  51.766018
#  7         deg_in_Genetic_Algorithms    9.120373  43.726751
#  8                 deg_in_Case_Based    8.536772  36.944579
#  9                              pca2    4.991211   6.497107
#  10             deg_in_Rule_Learning    4.588982  18.518189
#  11                             pca3    3.840943   1.947796
#
# [OutputCasTables]
#
#              casLib                 Name  Rows  Columns  \
#  0  CASUSER(brrees)  topNForestModelLeaf  1660       35
#
#                                              casTable
#  0  CASTable('topNForestModelLeaf', caslib='CASUSE...
#
# + Elapsed: 0.29s, user: 1.32s, sys: 0.853s, mem: 165mb

# %%
resultsScoreTopNForestModel=demo.scoreForestModel(topNForestModel,"contentTestPcaNetwork")
# Out:
# Accuracy = 0.7933579335793358

# %% [markdown]
# ### Bootstrap Runs

# %%
# %%time
accuracies = demo.bootstrapForestModel(topNForestModel,"contentTrainPcaNetwork",
                                       "contentTestPcaNetwork",
                                       topNFeatureList,
                                       n=25
                                      );
# Out:
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5678 for sampling.
# NOTE: 1323010 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7950819672131147
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5679 for sampling.
# NOTE: 1322994 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7889344262295082
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5680 for sampling.
# NOTE: 1313522 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7889344262295082
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5681 for sampling.
# NOTE: 1311930 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7889344262295082
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5682 for sampling.
# NOTE: 1308666 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7930327868852459
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5683 for sampling.
# NOTE: 1300738 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7991803278688525
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5684 for sampling.
# NOTE: 1302362 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7868852459016393
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5685 for sampling.
# NOTE: 1305562 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7950819672131147
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5686 for sampling.
# NOTE: 1297730 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7807377049180327
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5687 for sampling.
# NOTE: 1294610 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7868852459016393
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5688 for sampling.
# NOTE: 1293050 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7807377049180327
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5689 for sampling.
# NOTE: 1288322 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7868852459016393
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5690 for sampling.
# NOTE: 1289914 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7827868852459017
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5691 for sampling.
# NOTE: 1289914 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.805327868852459
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5692 for sampling.
# NOTE: 1297842 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7848360655737705
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5693 for sampling.
# NOTE: 1291490 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7868852459016393
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5694 for sampling.
# NOTE: 1294674 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7950819672131147
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5695 for sampling.
# NOTE: 1291458 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7868852459016393
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5696 for sampling.
# NOTE: 1291458 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7786885245901639
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5697 for sampling.
# NOTE: 1293034 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7971311475409836
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5698 for sampling.
# NOTE: 1296266 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8012295081967213
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5699 for sampling.
# NOTE: 1293082 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7889344262295082
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5700 for sampling.
# NOTE: 1299386 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7991803278688525
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5701 for sampling.
# NOTE: 1302554 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7971311475409836
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5702 for sampling.
# NOTE: 1294642 bytes were written to the table "topNForestModelLeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.7950819672131147
# Bootstrap Accuracy = 0.7908196721311476 +- 0.006806734259680895
# CPU times: user 3.28 s, sys: 109 ms, total: 3.39 s
# Wall time: 13.5 s

# %% [markdown]
# ## Autotune Forest Model Using Top N Leaf Based Features

# %%
topNForestModelAuto = f"topNForestModelAuto{topNCutoff}Leaf"

# %%
# %%time
bestConfigTopN = demo.loadOrTuneForestModel(topNForestModelAuto,
                           "contentTrainPcaNetwork",
                           topNFeatureList
                          )
print(bestConfigTopN)
# Out:
# NOTE: Cloud Analytic Services made the file topNForestModelAuto12LeafAStore.sashdat available as table TOPNFORESTMODELAUTO12LEAFASTORE in caslib CASUSER(brrees).
# NOTE: Cloud Analytic Services made the file topNForestModelAuto12Leaf.sashdat available as table TOPNFORESTMODELAUTO12LEAF in caslib CASUSER(brrees).
# Best Configuration
#
#                                      Parameter       Value
# Name
# Evaluation                          Evaluation          72
# NTREE                          Number of Trees          98
# M                   Number of Variables to Try           4
# BOOTSTRAP                            Bootstrap  0.20442693
# MAXLEVEL                   Maximum Tree Levels          21
# NBINS                           Number of Bins          50
# Objective   Misclassification Error Percentage        9.83
# CPU times: user 15.6 ms, sys: 31.2 ms, total: 46.9 ms
# Wall time: 101 ms

# %%
resultsScoreTopNForestModelAuto=demo.scoreForestModel(topNForestModelAuto,"contentTestPcaNetwork")
# Out:
# Accuracy = 0.8708487084870848

# %% [markdown]
# ### Bootstrap Runs

# %%
# %%time
accuracies = demo.bootstrapForestModel(topNForestModelAuto,"contentTrainPcaNetwork",
                                       "contentTestPcaNetwork",
                                       topNFeatureList,
                                       bestConfigTopN,
                                       25
                                      );
# Out:
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5678 for sampling.
# NOTE: 4221130 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.860655737704918
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5679 for sampling.
# NOTE: 4207834 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8504098360655737
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5680 for sampling.
# NOTE: 4209730 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8565573770491803
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5681 for sampling.
# NOTE: 4196546 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8524590163934426
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5682 for sampling.
# NOTE: 4210210 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8627049180327869
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5683 for sampling.
# NOTE: 4211674 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8668032786885246
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5684 for sampling.
# NOTE: 4229826 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8545081967213115
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5685 for sampling.
# NOTE: 4234794 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8668032786885246
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5686 for sampling.
# NOTE: 4223298 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8565573770491803
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5687 for sampling.
# NOTE: 4223346 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8586065573770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5688 for sampling.
# NOTE: 4216642 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8565573770491803
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5689 for sampling.
# NOTE: 4206786 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.860655737704918
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5690 for sampling.
# NOTE: 4209970 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8545081967213115
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5691 for sampling.
# NOTE: 4208634 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8668032786885246
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5692 for sampling.
# NOTE: 4200402 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8504098360655737
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5693 for sampling.
# NOTE: 4184034 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8483606557377049
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5694 for sampling.
# NOTE: 4185562 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8565573770491803
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5695 for sampling.
# NOTE: 4172138 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8565573770491803
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5696 for sampling.
# NOTE: 4175242 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8524590163934426
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5697 for sampling.
# NOTE: 4178954 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8668032786885246
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5698 for sampling.
# NOTE: 4167938 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8647540983606558
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5699 for sampling.
# NOTE: 4166458 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8586065573770492
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5700 for sampling.
# NOTE: 4173098 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.860655737704918
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5701 for sampling.
# NOTE: 4184354 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.860655737704918
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=5702 for sampling.
# NOTE: 4179146 bytes were written to the table "topNForestModelAuto12LeafAStore" in the caslib "CASUSER(brrees)".
# Accuracy = 0.8586065573770492
# Bootstrap Accuracy = 0.8583606557377048 +- 0.005322191174015716
# CPU times: user 3.41 s, sys: 250 ms, total: 3.66 s
# Wall time: 28.2 s

# %% [markdown]
# # Session Cleanup

# %%
s.terminate();
